# %%
from qiskit_alice_bob_provider import AliceBobLocalProvider
from qiskit import QuantumCircuit, execute, transpile

provider = AliceBobLocalProvider()

circ = QuantumCircuit(2, 2)
circ.initialize('0+')
circ.cx(0, 1)
circ.measure(0, 0)
circ.measure(1, 1)

# Default 6-qubit QPU with the ratio of memory dissipation rates set to
# k1/k2=1e-5 and cat size, average_nb_photons, set to 16.
backend = provider.get_backend('EMU:6Q:PHYSICAL_CATS')

print(transpile(circ, backend).draw())
# *Displays a timed and scheduled circuit*

print(execute(circ, backend, shots=100000).result().get_counts())
# {'11': 49823, '00': 50177}

# Changing the cat size from 16 (default) to 4 and k1/k2 to 1e-2.
backend = provider.get_backend(
    'EMU:6Q:PHYSICAL_CATS', average_nb_photons=4, kappa_2=1e4
)
print(execute(circ, backend, shots=100000).result().get_counts())
# {'01': 557, '11': 49422, '10': 596, '00': 49425}
# Out:
# ---------------------------------------------------------------------------
# TranspilerError                           Traceback (most recent call last)
# Cell In[2], line 16
#      12 # Default 6-qubit QPU with the ratio of memory dissipation rates set to
#      13 # k1/k2=1e-5 and cat size, average_nb_photons, set to 16.
#      14 backend = provider.get_backend('EMU:6Q:PHYSICAL_CATS')
# ---> 16 print(transpile(circ, backend).draw())
#      17 # *Displays a timed and scheduled circuit*
#      19 print(execute(circ, backend, shots=100000).result().get_counts())
#
# File c:\Users\simon\.conda\envs\alice-bob\Lib\site-packages\qiskit\compiler\transpiler.py:419, in transpile(circuits, backend, basis_gates, inst_map, coupling_map, backend_properties, initial_layout, layout_method, routing_method, translation_method, scheduling_method, instruction_durations, dt, approximation_degree, timing_constraints, seed_transpiler, optimization_level, callback, output_name, unitary_synthesis_method, unitary_synthesis_plugin_config, target, hls_config, init_method, optimization_method, ignore_backend_supplied_default_methods)
#     391         instruction_durations = _parse_instruction_durations(
#     392             backend, instruction_durations, dt, circuits[0]
#     393         )
#     395 pm = generate_preset_pass_manager(
#     396     optimization_level,
#     397     backend=backend,
#    (...)
#     417     _skip_target=_skip_target,
#     418 )
# --> 419 out_circuits = pm.run(circuits, callback=callback)
#     420 for name, circ in zip(output_name, out_circuits):
#     421     circ.name = name
#
# File c:\Users\simon\.conda\envs\alice-bob\Lib\site-packages\qiskit\transpiler\passmanager.py:537, in StagedPassManager.run(self, circuits, output_name, callback)
#     530 def run(
#     531     self,
#     532     circuits: _CircuitsT,
#     533     output_name: str | None = None,
#     534     callback: Callable | None = None,
#     535 ) -> _CircuitsT:
#     536     self._update_passmanager()
# --> 537     return super().run(circuits, output_name, callback)
#
# File c:\Users\simon\.conda\envs\alice-bob\Lib\site-packages\qiskit\transpiler\passmanager.py:233, in PassManager.run(self, circuits, output_name, callback)
#     231     return self._run_single_circuit(circuits, output_name, callback)
#     232 if len(circuits) == 1:
# --> 233     return [self._run_single_circuit(circuits[0], output_name, callback)]
#     234 return self._run_several_circuits(circuits, output_name, callback)
#
# File c:\Users\simon\.conda\envs\alice-bob\Lib\site-packages\qiskit\transpiler\passmanager.py:292, in PassManager._run_single_circuit(self, circuit, output_name, callback)
#     280 """Run all the passes on a ``circuit``.
#     281
#     282 Args:
#    (...)
#     289     The transformed circuit.
#     290 """
#     291 running_passmanager = self._create_running_passmanager()
# --> 292 result = running_passmanager.run(circuit, output_name=output_name, callback=callback)
#     293 self.property_set = running_passmanager.property_set
#     294 return result
#
# File c:\Users\simon\.conda\envs\alice-bob\Lib\site-packages\qiskit\transpiler\runningpassmanager.py:125, in RunningPassManager.run(***failed resolving arguments***)
#     123 for passset in self.working_list:
#     124     for pass_ in passset:
# --> 125         dag = self._do_pass(pass_, dag, passset.options)
#     127 circuit = dag_to_circuit(dag, copy_operations=False)
#     128 if output_name:
#
# File c:\Users\simon\.conda\envs\alice-bob\Lib\site-packages\qiskit\transpiler\runningpassmanager.py:173, in RunningPassManager._do_pass(self, pass_, dag, options)
#     171 # Run the pass itself, if not already run
#     172 if pass_ not in self.valid_passes:
# --> 173     dag = self._run_this_pass(pass_, dag)
#     175     # update the valid_passes property
#     176     self._update_valid_passes(pass_)
#
# File c:\Users\simon\.conda\envs\alice-bob\Lib\site-packages\qiskit\transpiler\runningpassmanager.py:202, in RunningPassManager._run_this_pass(self, pass_, dag)
#     199 if pass_.is_transformation_pass:
#     200     # Measure time if we have a callback or logging set
#     201     start_time = time()
# --> 202     new_dag = pass_.run(dag)
#     203     end_time = time()
#     204     run_time = end_time - start_time
#
# File c:\Users\simon\.conda\envs\alice-bob\Lib\site-packages\qiskit\transpiler\passes\basis\basis_translator.py:207, in BasisTranslator.run(self, dag)
#     202 logger.info(
#     203     "Basis translation path search completed in %.3fs.", search_end_time - search_start_time
#     204 )
#     206 if basis_transforms is None:
# --> 207     raise TranspilerError(
#     208         "Unable to translate the operations in the circuit: "
#     209         f"{[x[0] for x in source_basis]} to the backend's (or manually specified) target "
#     210         f"basis: {list(target_basis)}. This likely means the target basis is not universal "
#     211         "or there are additional equivalence rules needed in the EquivalenceLibrary being "
#     212         "used. For more details on this error see: "
#     213         "https://qiskit.org/documentation/stubs/qiskit.transpiler.passes.BasisTranslator."
#     214         "html#translation_errors"
#     215     )
#     217 # Compose found path into a set of instruction substitution rules.
#     219 compose_start_time = time.time()
#
# TranspilerError: "Unable to translate the operations in the circuit: ['measure', 'cx', 'initialize', 'h'] to the backend's (or manually specified) target basis: ['initialize', 'measure', 'snapshot', 'rz', 'measure_x', 'x', 'delay', 'barrier', 'z', 'cx']. This likely means the target basis is not universal or there are additional equivalence rules needed in the EquivalenceLibrary being used. For more details on this error see: https://qiskit.org/documentation/stubs/qiskit.transpiler.passes.BasisTranslator.html#translation_errors"
